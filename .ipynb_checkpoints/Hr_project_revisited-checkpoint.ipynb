# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.colors import ListedColormap
import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.ensemble import RandomForestClassifier

# %%
survey= pd.read_csv("Data/employee_survey_data.csv")
#survey.columns= survey.columns.str.lower()
survey
# Out:
#       EmployeeID  EnvironmentSatisfaction  JobSatisfaction  WorkLifeBalance
# 0              1                      3.0              4.0              2.0
# 1              2                      3.0              2.0              4.0
# 2              3                      2.0              2.0              1.0
# 3              4                      4.0              4.0              3.0
# 4              5                      4.0              1.0              3.0
# ...          ...                      ...              ...              ...
# 4405        4406                      4.0              1.0              3.0
# 4406        4407                      4.0              4.0              3.0
# 4407        4408                      1.0              3.0              3.0
# 4408        4409                      4.0              1.0              3.0
# 4409        4410                      1.0              3.0              NaN
#
# [4410 rows x 4 columns]

# %%
general= pd.read_csv('Data/general_data.csv')
general
#general.columns= general.columns.str.lower()
general
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
manager= pd.read_csv('Data/manager_survey_data.csv')
#manager.columns= manager.columns.str.lower()
manager
# Out:
#       EmployeeID  JobInvolvement  PerformanceRating
# 0              1               3                  3
# 1              2               2                  4
# 2              3               3                  3
# 3              4               2                  3
# 4              5               3                  3
# ...          ...             ...                ...
# 4405        4406               3                  3
# 4406        4407               2                  3
# 4407        4408               3                  4
# 4408        4409               2                  3
# 4409        4410               4                  3
#
# [4410 rows x 3 columns]

# %%
general= pd.merge(pd.merge(general, survey,on="EmployeeID", how = "inner"), manager, on="EmployeeID")
general.columns= general.columns.str.lower()
general
# Out:
#       age attrition     businesstravel              department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       distancefromhome  education educationfield  employeecount  employeeid  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
general.set_index('employeeid',inplace=True)
general.head()
# Out:
#             age attrition     businesstravel              department  \
# employeeid
# 1            51        No      Travel_Rarely                   Sales
# 2            31       Yes  Travel_Frequently  Research & Development
# 3            32        No  Travel_Frequently  Research & Development
# 4            38        No         Non-Travel  Research & Development
# 5            32        No      Travel_Rarely  Research & Development
#
#             distancefromhome  education educationfield  employeecount  gender  \
# employeeid
# 1                          6          2  Life Sciences              1  Female
# 2                         10          1  Life Sciences              1  Female
# 3                         17          4          Other              1    Male
# 4                          2          5  Life Sciences              1    Male
# 5                         10          1        Medical              1    Male
#
# ...

# %%
in_time= pd.read_csv('Data/in_time.csv')
in_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 09:43:45  2015-01-05 10:08:48
# 1           2         NaN  2015-01-02 10:15:44  2015-01-05 10:21:05
# 2           3         NaN  2015-01-02 10:17:41  2015-01-05 09:50:50
# 3           4         NaN  2015-01-02 10:05:06  2015-01-05 09:56:32
# 4           5         NaN  2015-01-02 10:28:17  2015-01-05 09:49:58
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 09:54:26  2015-01-07 09:34:31  2015-01-08 09:51:09
# 1                  NaN  2015-01-07 09:45:17  2015-01-08 10:09:04
# 2  2015-01-06 10:14:13  2015-01-07 09:47:27  2015-01-08 10:03:40
# 3  2015-01-06 10:11:07  2015-01-07 09:37:30  2015-01-08 10:02:08
# 4  2015-01-06 09:45:28  2015-01-07 09:49:37  2015-01-08 10:19:44
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 10:09:25  2015-01-12 09:42:53  2015-01-13 10:13:06         NaN
# ...

# %%
out_time = pd.read_csv('Data/out_time.csv')
out_time.head()
# Out:
#    Unnamed: 0  2015-01-01           2015-01-02           2015-01-05  \
# 0           1         NaN  2015-01-02 16:56:15  2015-01-05 17:20:11
# 1           2         NaN  2015-01-02 18:22:17  2015-01-05 17:48:22
# 2           3         NaN  2015-01-02 16:59:14  2015-01-05 17:06:46
# 3           4         NaN  2015-01-02 17:25:24  2015-01-05 17:14:03
# 4           5         NaN  2015-01-02 18:31:37  2015-01-05 17:49:15
#
#             2015-01-06           2015-01-07           2015-01-08  \
# 0  2015-01-06 17:19:05  2015-01-07 16:34:55  2015-01-08 17:08:32
# 1                  NaN  2015-01-07 17:09:06  2015-01-08 17:34:04
# 2  2015-01-06 16:38:32  2015-01-07 16:33:21  2015-01-08 17:24:22
# 3  2015-01-06 17:07:42  2015-01-07 16:32:40  2015-01-08 16:53:11
# 4  2015-01-06 17:26:25  2015-01-07 17:37:59  2015-01-08 17:59:28
#
#             2015-01-09           2015-01-12           2015-01-13  2015-01-14  \
# 0  2015-01-09 17:38:29  2015-01-12 16:58:39  2015-01-13 18:02:58         NaN
# ...

# %%
total_time= in_time.append(out_time)

# %%
total_time = total_time.dropna(axis=1, how='all')

# %%
total_time = total_time.fillna(0)

# %%
total_time.iloc[:,1:]= total_time.iloc[:,1:].apply(pd.to_datetime, errors='coerce')

# %%
total_time = total_time.diff(periods=4410)
total_time = total_time.iloc[4410:].reset_index(drop=True)
total_time
# Out:
#       Unnamed: 0      2015-01-02      2015-01-05      2015-01-06  \
# 0            0.0 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39
# 1            0.0 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00
# 2            0.0 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19
# 3            0.0 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35
# 4            0.0 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57
# ...          ...             ...             ...             ...
# 4405         0.0 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58
# 4406         0.0 0 days 06:15:20 0 days 00:00:00 0 days 05:23:37
# 4407         0.0 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29
# 4408         0.0 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18
# 4409         0.0 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40
#
#           2015-01-07      2015-01-08      2015-01-09      2015-01-12  \
# 0    0 days 07:00:24 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46
# ...

# %%
total_time.drop(columns=['Unnamed: 0'],axis=1,inplace=True)
total_time.index = range(1,len(total_time)+1)

# %%
from pandas import TimedeltaIndex
import datetime

# %%
total_time['mean_time'] = total_time.mean(axis=1)
total_time.head()
# Out:
#        2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 1 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 2 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 3 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 4 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 5 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
#
#        2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# 1 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46 0 days 07:49:52
# 2 0 days 07:25:00 0 days 07:09:03 0 days 07:36:41 0 days 07:16:44
# 3 0 days 07:20:42 0 days 06:51:41 0 days 07:25:07 0 days 06:59:59
# 4 0 days 06:51:03 0 days 07:11:35 0 days 06:59:55 0 days 07:18:23
# 5 0 days 07:39:44 0 days 07:43:18 0 days 08:21:54 0 days 08:15:26
#
#        2015-01-15      2015-01-16      2015-01-19      2015-01-20  \
# 1 0 days 07:20:49 0 days 07:16:03 0 days 00:00:00 0 days 06:46:33
# ...

# %%
# convert mean time into hours
total_time['mean_time'] = total_time['mean_time'] / np.timedelta64(1, 'h')

# %%
total_time.head()
# Out:
#        2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 1 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 2 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 3 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 4 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 5 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
#
#        2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# 1 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46 0 days 07:49:52
# 2 0 days 07:25:00 0 days 07:09:03 0 days 07:36:41 0 days 07:16:44
# 3 0 days 07:20:42 0 days 06:51:41 0 days 07:25:07 0 days 06:59:59
# 4 0 days 06:51:03 0 days 07:11:35 0 days 06:59:55 0 days 07:18:23
# 5 0 days 07:39:44 0 days 07:43:18 0 days 08:21:54 0 days 08:15:26
#
#        2015-01-15      2015-01-16      2015-01-19      2015-01-20  \
# 1 0 days 07:20:49 0 days 07:16:03 0 days 00:00:00 0 days 06:46:33
# ...

# %%
## 
total_time.index = range(1,len(total_time)+1)

# %% [markdown]
# # Data Cleaning

# %%
#dealing with null values
general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4410 entries, 1 to 4410
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      4410 non-null   int64
#  1   attrition                4410 non-null   object
#  2   businesstravel           4410 non-null   object
#  3   department               4410 non-null   object
#  4   distancefromhome         4410 non-null   int64
#  5   education                4410 non-null   int64
#  6   educationfield           4410 non-null   object
#  7   employeecount            4410 non-null   int64
#  8   gender                   4410 non-null   object
#  9   joblevel                 4410 non-null   int64
#  10  jobrole                  4410 non-null   object
#  11  maritalstatus            4410 non-null   object
#  12  monthlyincome            4410 non-null   int64
#  13  numcompaniesworked       4391 non-null   float64
# ...

# %%
## Replacing null value with 0: : numcompaniesworked
np.where(general['numcompaniesworked'].isnull())[0]
# Out:
# array([ 115,  210,  343,  476,  647,  799,  932, 1103, 1312, 1521, 1711,
#        1996, 2365, 2696, 3063, 3533, 3910, 4226, 4395])

# %%
general['numcompaniesworked'] = general['numcompaniesworked'].fillna(value = 0)

# %%
## Replacing null value with mode
for column in general:
    general[column].fillna(general[column].mode()[0], inplace=True)

# %%
general.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4410 entries, 1 to 4410
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      4410 non-null   int64
#  1   attrition                4410 non-null   object
#  2   businesstravel           4410 non-null   object
#  3   department               4410 non-null   object
#  4   distancefromhome         4410 non-null   int64
#  5   education                4410 non-null   int64
#  6   educationfield           4410 non-null   object
#  7   employeecount            4410 non-null   int64
#  8   gender                   4410 non-null   object
#  9   joblevel                 4410 non-null   int64
#  10  jobrole                  4410 non-null   object
#  11  maritalstatus            4410 non-null   object
#  12  monthlyincome            4410 non-null   int64
#  13  numcompaniesworked       4410 non-null   float64
# ...

# %%
## Dropping not informative columns
general = general.drop(['over18','employeecount', 'standardhours' ], axis = 1)

# %%
general.head()
# Out:
#             age attrition     businesstravel              department  \
# employeeid
# 1            51        No      Travel_Rarely                   Sales
# 2            31       Yes  Travel_Frequently  Research & Development
# 3            32        No  Travel_Frequently  Research & Development
# 4            38        No         Non-Travel  Research & Development
# 5            32        No      Travel_Rarely  Research & Development
#
#             distancefromhome  education educationfield  gender  joblevel  \
# employeeid
# 1                          6          2  Life Sciences  Female         1
# 2                         10          1  Life Sciences  Female         1
# 3                         17          4          Other    Male         4
# 4                          2          5  Life Sciences    Male         3
# 5                         10          1        Medical    Male         1
#
#                               jobrole maritalstatus  monthlyincome  \
# employeeid
# ...

# %%
# Rename index as emID to add the general data set
total_time = total_time.rename(columns = {'index' : 'employeeid'})
total_time.head()
# Out:
#        2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 1 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 2 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 3 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 4 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 5 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
#
#        2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# 1 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46 0 days 07:49:52
# 2 0 days 07:25:00 0 days 07:09:03 0 days 07:36:41 0 days 07:16:44
# 3 0 days 07:20:42 0 days 06:51:41 0 days 07:25:07 0 days 06:59:59
# 4 0 days 06:51:03 0 days 07:11:35 0 days 06:59:55 0 days 07:18:23
# 5 0 days 07:39:44 0 days 07:43:18 0 days 08:21:54 0 days 08:15:26
#
#        2015-01-15      2015-01-16      2015-01-19      2015-01-20  \
# 1 0 days 07:20:49 0 days 07:16:03 0 days 00:00:00 0 days 06:46:33
# ...

# %%
# merge mean_time and general
general = general.join(total_time['mean_time'], on = 'employeeid', how = 'inner')
general.head()
# Out:
#             age attrition     businesstravel              department  \
# employeeid
# 1            51        No      Travel_Rarely                   Sales
# 2            31       Yes  Travel_Frequently  Research & Development
# 3            32        No  Travel_Frequently  Research & Development
# 4            38        No         Non-Travel  Research & Development
# 5            32        No      Travel_Rarely  Research & Development
#
#             distancefromhome  education educationfield  gender  joblevel  \
# employeeid
# 1                          6          2  Life Sciences  Female         1
# 2                         10          1  Life Sciences  Female         1
# 3                         17          4          Other    Male         4
# 4                          2          5  Life Sciences    Male         3
# 5                         10          1        Medical    Male         1
#
#                               jobrole maritalstatus  monthlyincome  \
# employeeid
# ...

# %%
# save the dataframe
general.to_csv('Data/general_hr_mean_time.csv')

# %% [markdown]
# # Data Processing

# %%
## we want plot certain wroking groups (according to ages) across a year

# %%
general.hist(column='age')
# Out:
# array([[<AxesSubplot:title={'center':'age'}>]], dtype=object)

# %%
general['age_binned'] = pd.cut(general.age, bins=4, labels=['18-30', '31-40', '41-50', '51-60'])

# %%
general.head()
# Out:
#             age attrition     businesstravel              department  \
# employeeid
# 1            51        No      Travel_Rarely                   Sales
# 2            31       Yes  Travel_Frequently  Research & Development
# 3            32        No  Travel_Frequently  Research & Development
# 4            38        No         Non-Travel  Research & Development
# 5            32        No      Travel_Rarely  Research & Development
#
#             distancefromhome  education educationfield  gender  joblevel  \
# employeeid
# 1                          6          2  Life Sciences  Female         1
# 2                         10          1  Life Sciences  Female         1
# 3                         17          4          Other    Male         4
# 4                          2          5  Life Sciences    Male         3
# 5                         10          1        Medical    Male         1
#
#                               jobrole maritalstatus  monthlyincome  \
# employeeid
# ...

# %%
total_time.drop(columns='mean_time', inplace=True)

# %%
#total_time = total_time.T

# %%
#total_time.index = pd.to_datetime(total_time.index)

# %%
total_time.head()
# Out:
#        2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 1 0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 2 0 days 08:06:33 0 days 07:27:17 0 days 00:00:00 0 days 07:23:49
# 3 0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 4 0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 5 0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
#
#        2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# 1 0 days 07:17:23 0 days 07:29:04 0 days 07:15:46 0 days 07:49:52
# 2 0 days 07:25:00 0 days 07:09:03 0 days 07:36:41 0 days 07:16:44
# 3 0 days 07:20:42 0 days 06:51:41 0 days 07:25:07 0 days 06:59:59
# 4 0 days 06:51:03 0 days 07:11:35 0 days 06:59:55 0 days 07:18:23
# 5 0 days 07:39:44 0 days 07:43:18 0 days 08:21:54 0 days 08:15:26
#
#        2015-01-15      2015-01-16      2015-01-19      2015-01-20  \
# 1 0 days 07:20:49 0 days 07:16:03 0 days 00:00:00 0 days 06:46:33
# ...

# %%
total_time_binned_age = total_time.join(general['age_binned'], how = 'inner')

# %%
total_time_binned_age = total_time_binned_age.pivot_table(columns='age_binned')
total_time_binned_age
# Out:
# age_binned                     18-30                     31-40  \
# 2015-01-02 0 days 07:24:50.465116279 0 days 07:17:55.974879227
# 2015-01-05 0 days 07:21:00.034883720 0 days 07:19:16.628502415
# 2015-01-06 0 days 07:28:01.484496124 0 days 07:19:40.804830917
# 2015-01-07 0 days 07:19:34.098191214 0 days 07:21:03.289371980
# 2015-01-08 0 days 07:21:41.757105943 0 days 07:15:47.739613526
# ...                              ...                       ...
# 2015-12-24 0 days 07:22:15.492248062 0 days 07:16:00.500966183
# 2015-12-28 0 days 07:22:29.248062015 0 days 07:17:33.521739130
# 2015-12-29 0 days 07:16:52.572351421 0 days 07:16:09.683091787
# 2015-12-30 0 days 07:15:19.443152454 0 days 07:15:17.807729468
# 2015-12-31 0 days 07:22:59.399224806 0 days 07:20:24.695652173
#
# age_binned                     41-50                     51-60
# 2015-01-02 0 days 07:20:47.411652340 0 days 07:20:26.445086705
# 2015-01-05 0 days 07:22:13.950334288 0 days 07:22:32.905587668
# ...

# %%
#daily working hours per age groups
total_hour_binned_age = total_time_binned_age / np.timedelta64(1, 'h')
total_hour_binned_age
# Out:
# age_binned     18-30     31-40     41-50     51-60
# 2015-01-02  7.414018  7.298882  7.346503  7.340679
# 2015-01-05  7.350010  7.321286  7.370542  7.375807
# 2015-01-06  7.467079  7.328001  7.120478  7.379090
# 2015-01-07  7.326138  7.350914  7.296410  7.426879
# 2015-01-08  7.361599  7.263261  7.249464  7.331962
# ...              ...       ...       ...       ...
# 2015-12-24  7.370970  7.266806  7.203724  7.333270
# 2015-12-28  7.374791  7.292645  7.275655  7.277650
# 2015-12-29  7.281270  7.269356  7.359727  7.395355
# 2015-12-30  7.255401  7.254947  7.223158  7.252646
# 2015-12-31  7.383166  7.340193  7.246894  7.426339
#
# [249 rows x 4 columns]

# %%
#let's aggregate per months
total_hour_binned_age.index = pd.to_datetime(total_hour_binned_age.index)
total_hour_binned_age
# Out:
# age_binned     18-30     31-40     41-50     51-60
# 2015-01-02  7.414018  7.298882  7.346503  7.340679
# 2015-01-05  7.350010  7.321286  7.370542  7.375807
# 2015-01-06  7.467079  7.328001  7.120478  7.379090
# 2015-01-07  7.326138  7.350914  7.296410  7.426879
# 2015-01-08  7.361599  7.263261  7.249464  7.331962
# ...              ...       ...       ...       ...
# 2015-12-24  7.370970  7.266806  7.203724  7.333270
# 2015-12-28  7.374791  7.292645  7.275655  7.277650
# 2015-12-29  7.281270  7.269356  7.359727  7.395355
# 2015-12-30  7.255401  7.254947  7.223158  7.252646
# 2015-12-31  7.383166  7.340193  7.246894  7.426339
#
# [249 rows x 4 columns]

# %%
total_hour_binned_age.iloc[:,:4].plot(subplots=True, layout=(2, 2), figsize=(12, 5))
plt.suptitle('total_hour_binned_age')
plt.ylabel('hours (h)')
# Out:
# Text(0, 0.5, 'hours (h)')
